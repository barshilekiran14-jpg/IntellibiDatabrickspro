-- %%
%sql
-- ===== NEW: rawProduct  (external on AWS S3) =====
CREATE TABLE IF NOT EXISTS saleslake_dev.bronze_dev.rawProduct (
    product_id STRING, sku STRING, product_name STRING,
    category STRING, sub_category STRING, brand STRING,
    supplier STRING, unit_cost STRING, list_price STRING,
    launch_date STRING, status STRING,
    ingest_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslakekir/saleslake/dev/delta_table/bronze/product/';

CREATE TABLE IF NOT EXISTS saleslake_qa.bronze_qa.rawProduct (
    product_id STRING, sku STRING, product_name STRING,
    category STRING, sub_category STRING, brand STRING,
    supplier STRING, unit_cost STRING, list_price STRING,
    launch_date STRING, status STRING,
    ingest_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslakekir/saleslake/qa/delta_table/bronze/product/';

CREATE TABLE IF NOT EXISTS saleslake_prod.bronze_prod.rawProduct (
    product_id STRING, sku STRING, product_name STRING,
    category STRING, sub_category STRING, brand STRING,
    supplier STRING, unit_cost STRING, list_price STRING,
    launch_date STRING, status STRING,
    ingest_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslakekir/saleslake/prod/delta_table/bronze/product/';



-- ===== NEW: cleanedProduct  (external on AWS S3) =====
CREATE TABLE IF NOT EXISTS saleslake_dev.silver_dev.cleanedProduct (
    product_id STRING, sku STRING, product_name STRING,
    category STRING, sub_category STRING, brand STRING,
    supplier STRING, unit_cost DECIMAL(18,2), list_price DECIMAL(18,2),
    launch_date DATE, status STRING,
    ingest_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslakekir/saleslake/dev/delta_table/silver/product/';

CREATE TABLE IF NOT EXISTS saleslake_qa.silver_qa.cleanedProduct (
    product_id STRING, sku STRING, product_name STRING,
    category STRING, sub_category STRING, brand STRING,
    supplier STRING, unit_cost DECIMAL(18,2), list_price DECIMAL(18,2),
    launch_date DATE, status STRING,
    ingest_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslakekir/saleslake/qa/delta_table/silver/product/';

CREATE TABLE IF NOT EXISTS saleslake_prod.silver_prod.cleanedProduct (
    product_id STRING, sku STRING, product_name STRING,
    category STRING, sub_category STRING, brand STRING,
    supplier STRING, unit_cost DECIMAL(18,2), list_price DECIMAL(18,2),
    launch_date DATE, status STRING,
    ingest_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslakekir/saleslake/prod/delta_table/silver/product/';



CREATE TABLE IF NOT EXISTS saleslake_dev.gold_dev.tgt_product (
    product_sk BIGINT GENERATED ALWAYS AS IDENTITY,
    product_id INT, sku STRING, product_name STRING,
    category STRING, sub_category STRING, brand STRING,
    supplier STRING, unit_cost DECIMAL(18,2), list_price DECIMAL(18,2),
    launch_date DATE, status STRING,
    is_active STRING, rec_version INT,
    start_effective_ts TIMESTAMP, end_effective_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslakekir/saleslake/dev/delta_table/gold/product/';

CREATE TABLE IF NOT EXISTS saleslake_qa.gold_qa.tgt_product (
    product_sk BIGINT GENERATED ALWAYS AS IDENTITY,
    product_id INT, sku STRING, product_name STRING,
    category STRING, sub_category STRING, brand STRING,
    supplier STRING, unit_cost DECIMAL(18,2), list_price DECIMAL(18,2),
    launch_date DATE, status STRING,
    is_active STRING, rec_version INT,
    start_effective_ts TIMESTAMP, end_effective_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslakekir/saleslake/qa/delta_table/gold/product';

CREATE TABLE IF NOT EXISTS saleslake_prod.gold_prod.tgt_product (
    product_sk BIGINT GENERATED ALWAYS AS IDENTITY,
    product_id INT, sku STRING, product_name STRING,
    category STRING, sub_category STRING, brand STRING,
    supplier STRING, unit_cost DECIMAL(18,2), list_price DECIMAL(18,2),
    launch_date DATE, status STRING,
    is_active STRING, rec_version INT,
    start_effective_ts TIMESTAMP, end_effective_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslakekir/saleslake/prod/delta_table/gold/product';
