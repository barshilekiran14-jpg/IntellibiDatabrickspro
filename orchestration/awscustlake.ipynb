# %%
# %sql
CREATE OR REPLACE TABLE saleslake_dev.bronze_dev.rawCustomer
(
    customer_id string , customer_name string, email string, 
    phone string , address string , 
    city string , state string, 
    country string,zip_code string,
    segment string,
    ingest_ts timestamp
)using delta
location"s3://saleslakekir/saleslake/dev/delta_table/bronze/customer/";

-- -----------------------------------------------------------------

CREATE OR REPLACE TABLE saleslake_qa.bronze_qa.rawCustomer
(
    customer_id string , customer_name string, email string, 
    phone string , address string , 
    city string , state string, 
    country string,zip_code string,
    segment string,
    ingest_ts timestamp
)using delta
location"s3://saleslakekir/saleslake/qa/delta_table/bronze/customer/";

-- ------------------------------------------------

CREATE OR REPLACE TABLE saleslake_prod.bronze_prod.rawCustomer
(
    customer_id string , customer_name string, email string, 
    phone string , address string , 
    city string , state string, 
    country string,zip_code string,
    segment string,
    ingest_ts timestamp
)using delta
location"s3://saleslakekir/saleslake/prod/delta_table/bronze/customer/";


---------------------------------------------------------------------

CREATE OR REPLACE TABLE saleslake_prod.silver_prod.cleanCustomer
(
    customer_id string , customer_name string, email string, 
    phone string , address string , 
    city string , state string, 
    country string,zip_code string,
    segment string,
    ingest_ts timestamp
)using delta
location"s3://saleslakekir/saleslake/prod/delta_table/silver/customer/";

-----------------------------------------------------------------------

CREATE OR REPLACE TABLE saleslake_qa.silver_qa.cleanCustomer
(
    customer_id string , customer_name string, email string, 
    phone string , address string , 
    city string , state string, 
    country string,zip_code string,
    segment string,
    ingest_ts timestamp
)using delta
location"s3://saleslakekir/saleslake/qa/delta_table/silver/customer/";

----------------------------------------------------------------

CREATE OR REPLACE TABLE saleslake_dev.silver_dev.cleanCustomer
(
    customer_id string , customer_name string, email string, 
    phone string , address string , 
    city string , state string, 
    country string,zip_code string,
    segment string,
    ingest_ts timestamp
)using delta
location"s3://saleslakekir/saleslake/dev/delta_table/silver/customer/";

-------------------------------------------------------------------------------------

CREATE OR REPLACE TABLE saleslake_dev.gold_dev.tgtCustomer
(
    customer_sk BIGINT GENERATED ALWAYS AS IDENTITY,
    customer_id int , customer_name string, email string, 
    phone string , address string , 
    city string , state string, 
    country string,zip_code string,
    segment string,
    ingest_ts timestamp,
    is_active string,
    rec_version	int, 
    start_effective_ts	timestamp,
    end_effective_ts timestamp


)using delta
location"s3://saleslakekir/saleslake/dev/delta_table/gold/customer/";
-- -------------------------------------------------------------

CREATE OR REPLACE TABLE saleslake_qa.gold_qa.tgtCustomer
(
    customer_sk BIGINT GENERATED ALWAYS AS IDENTITY,
    customer_id int , customer_name string, email string, 
    phone string , address string , 
    city string , state string, 
    country string,zip_code string,
    segment string,
    ingest_ts timestamp,
    is_active string,
    rec_version	int, 
    start_effective_ts	timestamp,
    end_effective_ts timestamp

)using delta
location"s3://saleslakekir/saleslake/qa/delta_table/gold/customer/";


--------------------------------------------------------

CREATE OR REPLACE TABLE saleslake_prod.gold_prod.tgtCustomer
(
    customer_sk BIGINT GENERATED ALWAYS AS IDENTITY,
    customer_id int , customer_name string, email string, 
    phone string , address string , 
    city string , state string, 
    country string,zip_code string,
    segment string,
    ingest_ts timestamp,
    is_active string,
    rec_version	int, 
    start_effective_ts	timestamp,
    end_effective_ts timestamp

)using delta
location"s3://saleslakekir/saleslake/prod/delta_table/gold/customer/";

# %%
# %sql
-- drop table saleslake_prod.gold_prod.tgtCustomer


CREATE OR REPLACE TABLE saleslake_prod.gold_prod.tgtCustomer
(
    customer_sk BIGINT GENERATED ALWAYS AS IDENTITY,
    customer_id int , customer_name string, email string, 
    phone string , address string , 
    city string , state string, 
    country string,zip_code string,
    segment string,
    ingest_ts timestamp,
    is_active string,
    rec_version	int, 
    start_effective_ts	timestamp,
    end_effective_ts timestamp

)using delta
location"s3://saleslakekir/saleslake/prod/delta_table/gold/customer/";
