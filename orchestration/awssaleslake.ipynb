# %%
# dbutils.fs.mkdirs("s3://saleslakekir/saleslake/qa/")

# %%
# %sql
create table if not exists salesLake_dev.bronze_dev.rawmonthlysal
(
    sale_id string,
    product string,
    category string,
    quantity string,
    price string,
    sales_date string,
    region string,
    ingest_ts timestamp

)
using delta
location"s3://saleslakekir/saleslake/dev/delta_table/bronze/sales/";

create or replace table salesLake_prod.bronze_prod.rawmonthlysal
(
    sale_id string,
    product string,
    category string,
    quantity string,
    price string,
    sales_date string,
    region string,
    ingest_ts timestamp

)
using delta
location"s3://saleslakekir/saleslake/prod/delta_table/bronze/sales/";

create or replace table salesLake_qa.bronze_qa.rawmonthlysal
(
    sale_id string,
    product string,
    category string,
    quantity string,
    price string,
    sales_date string,
    region string,
    ingest_ts timestamp

)
using delta
location"s3://saleslakekir/saleslake/qa/delta_table/bronze/sales/";

----------------------------------------------------

create or replace table salesLake_dev.silver_dev.CleanseMonthlysal
(
    sale_id integer,
    product string,
    category string,
    quantity integer,
    price double,
    sale_date date,
    region string,
    ingest_ts timestamp

)
using delta
location"s3://saleslakekir/saleslake/dev/delta_table/silver/sales/";


create or replace table salesLake_qa.silver_qa.CleanseMonthlysal
(
    sale_id integer,
    product string,
    category string,
    quantity integer,
    price double,
    sale_date date,
    region string,
    ingest_ts timestamp

)
using delta
location"s3://saleslakekir/saleslake/qa/delta_table/silver/sales/";


create or replace table salesLake_prod.silver_prod.CleanseMonthlysal
(
    sale_id integer,
    product string,
    category string,
    quantity integer,
    price double,
    sale_date date,
    region string,
    ingest_ts timestamp

)
using delta
location"s3://saleslakekir/saleslake/prod/delta_table/silver/sales/";

----------------------------------------------------------------


create or replace table salesLake_dev.gold_dev.tgtmonth
(
    sale_id integer,
    product string,
    category string,
    quantity integer,
    price double,
    sale_date date,
    region string,
    initial_load_ts timestamp,
    last_updt_ts timestamp

)
using delta
location"s3://saleslakekir/saleslake/dev/delta_table/gold/sales/";



create or replace table salesLake_prod.gold_prod.tgtmonth
(
    sale_id integer,
    product string,
    category string,
    quantity integer,
    price double,
    sale_date date,
    region string,
    initial_load_ts timestamp,
    last_updt_ts timestamp

)
using delta
location"s3://saleslakekir/saleslake/prod/delta_table/gold/sales/";


create or replace table salesLake_qa.gold_qa.tgtmonth
(
    sale_id integer,
    product string,
    category string,
    quantity integer,
    price double,
    sale_date date,
    region string, 
    last_updt_ts timestamp

)
using delta
location"s3://saleslakekir/saleslake/qa/delta_table/gold/sales/";
