-- %%
 create or replace table saleslake_qa.bronze_qa.rawInvoice
 (
 invoice_id string,
 invoice_number string,
 customer_id string,
 invoice_date string,
 due_date string,
 subtotal_amount string,
 discount_code string,
 discount_amount string,
 tax_amount string,
 total_amount string,
 payment_status string,
 payment_method string,
 payment_date string,
 currency string,
 region string,
 store_id string,
 channel string,
 created_by string,
 ingest_ts timestamp
 )using delta
 location"s3://saleslakekir/saleslake/qa/delta_table/bronze/invoice/"
;



create or replace table saleslake_dev.bronze_dev.rawInvoice
 (
 invoice_id string,
 invoice_number string,
 customer_id string,
 invoice_date string,
 due_date string,
 subtotal_amount string,
 discount_code string,
 discount_amount string,
 tax_amount string,
 total_amount string,
 payment_status string,
 payment_method string,
 payment_date string,
 currency string,
 region string,
 store_id string,
 channel string,
 created_by string,
 ingest_ts timestamp
 )using delta
 location"s3://saleslakekir/saleslake/dev/delta_table/bronze/invoice/" ;
---------------------------------------------------------------------
 create or replace table saleslake_prod.bronze_prod.rawInvoice
 (
 invoice_id string,
 invoice_number string,
 customer_id string,
 invoice_date string,
 due_date string,
 subtotal_amount string,
 discount_code string,
 discount_amount string,
 tax_amount string,
 total_amount string,
 payment_status string,
 payment_method string,
 payment_date string,
 currency string,
 region string,
 store_id string,
 channel string,
 created_by string,
 ingest_ts timestamp
 )using delta
 location"s3://saleslakekir/saleslake/prod/delta_table/bronze/invoice/" ;

 --------------------------------------------------------------------------
 ---------------------------------------------------------------------------

 create or replace table saleslake_qa.silver_qa.cleanInvoice
 (
 invoice_id string,
 invoice_number string,
 customer_id int,
 invoice_date date,
 due_date date,
 subtotal_amount double,
 discount_code string,
 discount_amount int,
 tax_amount int,
 total_amount int,
 payment_status string,
 payment_method string,
 payment_date date,
 currency string,
 region string,
 store_id int,
 channel string,
 created_by string,
 ingest_ts timestamp
 )using delta
 location"s3://saleslakekir/saleslake/qa/delta_table/silver/invoice/";

-- Alter table saleslake_qa.silver_qa.rawInvoice Rename to saleslake_qa.silver_qa.cleanInvoice;
-------------------------------------------------------------------------

 create or replace table saleslake_prod.silver_prod.cleanInvoice
 (
 invoice_id string,
 invoice_number string,
 customer_id int,
 invoice_date date,
 due_date date,
 subtotal_amount double,
 discount_code string,
 discount_amount int,
 tax_amount int,
 total_amount int,
 payment_status string,
 payment_method string,
 payment_date date,
 currency string,
 region string,
 store_id int,
 channel string,
 created_by string,
 ingest_ts timestamp
 )using delta
 location"s3://saleslakekir/saleslake/prod/delta_table/silver/invoice/";

 -----------------------------------------------------------

 
 create or replace table saleslake_dev.silver_dev.cleanInvoice
 (
 invoice_id string,
 invoice_number string,
 customer_id int,
 invoice_date date,
 due_date date,
 subtotal_amount double,
 discount_code string,
 discount_amount int,
 tax_amount int,
 total_amount int,
 payment_status string,
 payment_method string,
 payment_date date,
 currency string,
 region string,
 store_id int,
 channel string,
 created_by string,
 ingest_ts timestamp
 )using delta
 location"s3://saleslakekir/saleslake/dev/delta_table/silver/invoice/";


---------------------------------------------------------------------


 create or replace table saleslake_prod.gold_prod.tgtInvoice
 (
 customer_sk BIGINT GENERATED ALWAYS AS IDENTITY,
 invoice_id string,
 invoice_number string,
 customer_id int,
 invoice_date date,
 due_date date,
 subtotal_amount double,
 discount_code string,
 discount_amount int,
 tax_amount int,
 total_amount int,
 payment_status string,
 payment_method string,
 payment_date date,
 currency string,
 region string,
 store_id int,
 channel string,
 created_by string,
 ingest_ts timestamp,
 is_active string,
 rec_version	int, 
 start_effective_ts	timestamp,
 end_effective_ts timestamp
 )using delta
 location"s3://saleslakekir/saleslake/prod/delta_table/gold/invoice/";

 ----------------------------------------------------------------------------------

  create or replace table saleslake_dev.gold_dev.tgtInvoice
 (
 customer_sk BIGINT GENERATED ALWAYS AS IDENTITY,
 invoice_id string,
 invoice_number string,
 customer_id int,
 invoice_date date,
 due_date date,
 subtotal_amount double,
 discount_code string,
 discount_amount int,
 tax_amount int,
 total_amount int,
 payment_status string,
 payment_method string,
 payment_date date,
 currency string,
 region string,
 store_id int,
 channel string,
 created_by string,
 ingest_ts timestamp,
 is_active string,
 rec_version	int, 
 start_effective_ts	timestamp,
 end_effective_ts timestamp
 )using delta
 location"s3://saleslakekir/saleslake/dev/delta_table/gold/invoice/";

 -----------------------------------


 create or replace table saleslake_qa.gold_qa.tgtInvoice
 (
    customer_sk BIGINT GENERATED ALWAYS AS IDENTITY,
 invoice_id string,
 invoice_number string,
 customer_id int,
 invoice_date date,
 due_date date,
 subtotal_amount double,
 discount_code string,
 discount_amount int,
 tax_amount int,
 total_amount int,
 payment_status string,
 payment_method string,
 payment_date date,
 currency string,
 region string,
 store_id int,
 channel string,
 created_by string,
 ingest_ts timestamp,
 is_active string,
 rec_version	int, 
 start_effective_ts	timestamp,
 end_effective_ts timestamp
 )using delta
 location"s3://saleslakekir/saleslake/qa/delta_table/gold/invoice/";
