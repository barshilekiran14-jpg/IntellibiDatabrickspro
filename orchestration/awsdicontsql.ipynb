# %%
# %sql
CREATE TABLE IF NOT EXISTS saleslake_dev.bronze_dev.rawDiscount (
    discount_id STRING, discount_code STRING, discount_name STRING,
    discount_type STRING, discount_value STRING,
    min_purchase_amount STRING, max_discount_amount STRING,
    valid_from STRING, valid_to STRING,
    applicable_segment STRING, applicable_category STRING,
    usage_limit_per_customer STRING, total_usage_limit STRING,
    is_active STRING, created_date STRING,
    ingest_ts TIMESTAMP
)USING delta
location 's3://saleslakekir/saleslake/dev/delta_table/bronze/discount/';

CREATE TABLE IF NOT EXISTS saleslake_qa.bronze_qa.rawDiscount (
    discount_id STRING, discount_code STRING, discount_name STRING,
    discount_type STRING, discount_value STRING,
    min_purchase_amount STRING, max_discount_amount STRING,
    valid_from STRING, valid_to STRING,
    applicable_segment STRING, applicable_category STRING,
    usage_limit_per_customer STRING, total_usage_limit STRING,
    is_active STRING, created_date STRING,
    ingest_ts TIMESTAMP
)USING delta
location 's3://saleslakekir/saleslake/qa/delta_table/bronze/discount/';

CREATE TABLE IF NOT EXISTS saleslake_prod.bronze_prod.rawDiscount (
    discount_id STRING, discount_code STRING, discount_name STRING,
    discount_type STRING, discount_value STRING,
    min_purchase_amount STRING, max_discount_amount STRING,
    valid_from STRING, valid_to STRING,
    applicable_segment STRING, applicable_category STRING,
    usage_limit_per_customer STRING, total_usage_limit STRING,
    is_active STRING, created_date STRING,
    ingest_ts TIMESTAMP
)USING delta
location 's3://saleslakekir/saleslake/prod/delta_table/bronze/discount/';













----------------------------------------------------------------------------------------------


CREATE TABLE IF NOT EXISTS saleslake_dev.silver_dev.cleanedDiscount (
    discount_id INT, discount_code STRING, discount_name STRING,
    discount_type STRING, discount_value DECIMAL(10,2),
    min_purchase_amount DECIMAL(18,2), max_discount_amount DECIMAL(18,2),
    valid_from DATE, valid_to DATE,
    applicable_segment STRING, applicable_category STRING,
    usage_limit_per_customer INT, total_usage_limit INT,
    is_active STRING, created_date DATE,
    ingest_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslakekir/saleslake/dev/delta_table/silver/discount/';

CREATE TABLE IF NOT EXISTS saleslake_qa.silver_qa.cleanedDiscount (
    discount_id INT, discount_code STRING, discount_name STRING,
    discount_type STRING, discount_value DECIMAL(10,2),
    min_purchase_amount DECIMAL(18,2), max_discount_amount DECIMAL(18,2),
    valid_from DATE, valid_to DATE,
    applicable_segment STRING, applicable_category STRING,
    usage_limit_per_customer INT, total_usage_limit INT,
    is_active STRING, created_date DATE,
    ingest_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslakekir/saleslake/qa/delta_table/silver/discount/';

CREATE TABLE IF NOT EXISTS saleslake_prod.silver_prod.cleanedDiscount (
    discount_id INT, discount_code STRING, discount_name STRING,
    discount_type STRING, discount_value DECIMAL(10,2),
    min_purchase_amount DECIMAL(18,2), max_discount_amount DECIMAL(18,2),
    valid_from DATE, valid_to DATE,
    applicable_segment STRING, applicable_category STRING,
    usage_limit_per_customer INT, total_usage_limit INT,
    is_active STRING, created_date DATE,
    ingest_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslakekir/saleslake/prod/delta_table/silver/discount/';

------------------------------------------------------------------------------



CREATE TABLE IF NOT EXISTS saleslake_dev.gold_dev.tgtdiscount (
    discount_sk BIGINT GENERATED ALWAYS AS IDENTITY,
    discount_id INT, discount_code STRING, discount_name STRING,
    discount_type STRING, discount_value DECIMAL(10,2),
    min_purchase_amount DECIMAL(18,2), max_discount_amount DECIMAL(18,2),
    valid_from DATE, valid_to DATE,
    applicable_segment STRING, applicable_category STRING,
    usage_limit_per_customer INT, total_usage_limit INT, status STRING,
    is_active STRING, rec_version INT,
    start_effective_ts TIMESTAMP, end_effective_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslakekir/saleslake/dev/delta_table/gold/discount/';

CREATE TABLE IF NOT EXISTS saleslake_qa.gold_qa.tgtdiscount (
    discount_sk BIGINT GENERATED ALWAYS AS IDENTITY,
    discount_id INT, discount_code STRING, discount_name STRING,
    discount_type STRING, discount_value DECIMAL(10,2),
    min_purchase_amount DECIMAL(18,2), max_discount_amount DECIMAL(18,2),
    valid_from DATE, valid_to DATE,
    applicable_segment STRING, applicable_category STRING,
    usage_limit_per_customer INT, total_usage_limit INT, status STRING,
    is_active STRING, rec_version INT,
    start_effective_ts TIMESTAMP, end_effective_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslakekir/saleslake/qa/delta_table/gold/discount/';

CREATE TABLE IF NOT EXISTS saleslake_prod.gold_prod.tgtdiscount (
    discount_sk BIGINT GENERATED ALWAYS AS IDENTITY,
    discount_id INT, discount_code STRING, discount_name STRING,
    discount_type STRING, discount_value DECIMAL(10,2),
    min_purchase_amount DECIMAL(18,2), max_discount_amount DECIMAL(18,2),
    valid_from DATE, valid_to DATE,
    applicable_segment STRING, applicable_category STRING,
    usage_limit_per_customer INT, total_usage_limit INT, status STRING,
    is_active STRING, rec_version INT,
    start_effective_ts TIMESTAMP, end_effective_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslakekir/saleslake/prod/delta_table/gold/discount/';
