-- %%
TRUNCATE TABLE saleslake_dev.bronze_dev.rawmonthlysales;
truncate table saleslake_qa.bronze_qa.rawmonthlysales;
truncate table saleslake_prod.bronze_prod.rawmonthlysales;


-----------------------------------------------------------------------

TRUNCATE TABLE saleslake_dev.silver_dev.CleanseMonthlysale;
TRUNCATE TABLE saleslake_qa.silver_qa.CleanseMonthlysale;
TRUNCATE TABLE saleslake_prod.silver_prod.CleanseMonthlysale;


-----------------------------------------------------------------------

TRUNCATE TABLE saleslake_dev.gold_dev.tgtmonthly;
TRUNCATE TABLE saleslake_qa.gold_qa.tgtmonthly;
TRUNCATE TABLE saleslake_prod.gold_prod.tgtmonthly;
