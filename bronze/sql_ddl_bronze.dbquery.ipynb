-- %%
create or replace table intellibi_catlog.intelischema.rawmonthlysales
(
    sale_id string,
    product string,
    category string,
    quantity string,
    price string,
    sale_date string,
    region string,
    ingest_ts timestamp

);
describe intellibi_catlog.intelischema.rawmonthlysales;
select * from intellibi_catlog.intelischema.rawmonthlysales;
truncate table intellibi_catlog.intelischema.rawmonthlysales;
-- drop table intellibi_catlog.intelischema.dfmonthlysales
