# %%
dbutils.widgets.dropdown(name = "environment", defaultValue= "dev",choices= ["dev","prod","qa"],label = "select Environment")

# %%
env = dbutils.widgets.get("environment")
print(env)

# %%
#saleslake_prd.bronze_prd.rawCustomer
brznTablName = f"s3://saleslakekir/saleslake/{env}/delta_table/bronze/customer/"
print(brznTablName)
srcFileLoc=f"s3://saleslakekir/saleslake/src_file/DatabricksSourceFile/customer.csv"
print(srcFileLoc)
#"

# %%
# Note: COPY INTO requires a table name, not a path to _delta_log
# Replace with actual catalog.schema.table name
table_name = f"saleslake_{env}.bronze_{env}.rawCustomer"

spark.sql(f"""
COPY INTO {table_name}
FROM (
    SELECT customer_id,customer_name,email,phone,address,city,state,country,zip_code,segment,
    current_timestamp() AS ingest_ts 
    FROM '{srcFileLoc}'
    )
FILEFORMAT = CSV
FORMAT_OPTIONS ('header' = 'true')
COPY_OPTIONS ('mergeSchema' = 'false')
"""
)

# %%
# %sql
SELECT * FROM saleslake_dev.bronze_dev.rawCustomer
