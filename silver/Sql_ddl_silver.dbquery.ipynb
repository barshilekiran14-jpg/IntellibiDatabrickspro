-- %%
create or replace table intellibi_catlog.intelischema.CleanseMonthlysale
(
    sale_id integer,
    product string,
    category string,
    quantity integer,
    price double,
    sale_date date,
    region string,
    ingest_ts timestamp

);
describe intellibi_catlog.intelischema.CleanseMonthlysale;
select * from intellibi_catlog.intelischema.CleanseMonthlysale;
truncate table intellibi_catlog.intelischema.CleanseMonthlysale;
