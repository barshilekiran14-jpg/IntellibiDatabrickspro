-- %%
create or replace table intellibi_catlog.intelischema.tgtmonthly
(
    sale_id integer,
    product string,
    category string,
    quantity integer,
    price double,
    sale_date date,
    region string,
    initial_load_ts timestamp,
    last_updt_ts timestamp

);
select * from intellibi_catlog.intelischema.tgtmonthly
