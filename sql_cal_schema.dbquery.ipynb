-- %%
create catalog if not exists salesLake_dev;
create catalog if not exists salesLake_prod;
create catalog if not exists salesLake_qa;


create schema if not exists salesLake_dev.bronze_dev;
create schema if not exists salesLake_dev.silver_dev;
create schema if not exists salesLake_dev.gold_dev;

create schema if not exists salesLake_prod.bronze_prod;
create schema if not exists salesLake_prod.silver_prod;
create schema if not exists salesLake_prod.gold_prod;

create schema if not exists salesLake_qa.bronze_qa;
create schema if not exists salesLake_qa.silver_qa;
create schema if not exists salesLake_qa.gold_qa;

create volume if not exists salesLake_dev.bronze_dev.vol_saleslake_src_dev;
create volume if not exists salesLake_prod.bronze_prod.vol_saleslake_src_prod;
create volume if not exists salesLake_qa.bronze_qa.vol_saleslake_src_qa;

create volume if not exists salesLake_dev.silver_dev.vol_saleslake_silver_dev;
create volume if not exists salesLake_prod.silver_prod.vol_saleslake_silver_prod;
create volume if not exists salesLake_qa.silver_qa.vol_saleslake_silver_qa;

create volume if not exists salesLake_dev.gold_dev.vol_saleslake_gold_dev;
create volume if not exists salesLake_prod.gold_prod.vol_saleslake_gold_prod;
create volume if not exists salesLake_qa.gold_qa.vol_saleslake_gold_qa;



-------------------------------------------------------------------

create or replace table salesLake_dev.bronze_dev.rawmonthlysales
(
    sale_id string,
    product string,
    category string,
    quantity string,
    price string,
    sales_date string,
    region string,
    ingest_ts timestamp

);
--------------------------------------------------------------------

create or replace table salesLake_prod.bronze_prod.rawmonthlysales
(
    sale_id string,
    product string,
    category string,
    quantity string,
    price string,
    sales_date string,
    region string,
    ingest_ts timestamp

);

---------------------------------------------

create or replace table salesLake_qa.bronze_qa.rawmonthlysales
(
    sale_id string,
    product string,
    category string,
    quantity string,
    price string,
    sales_date string,
    region string,
    ingest_ts timestamp

);

select  * from saleslake_dev.bronze_dev.rawmonthlysales;
select * from saleslake_qa.bronze_qa.rawmonthlysales;
select * from saleslake_prod.bronze_prod.rawmonthlysales;

-----------------------------------------------------------------------

select  * from saleslake_dev.silver_dev.CleanseMonthlysale;
select * from saleslake_qa.silver_qa.CleanseMonthlysale;
select * from saleslake_prod.silver_prod.CleanseMonthlysale;

-------------------------------------------------------------------

select  * from saleslake_dev.gold_dev.tgtmonthly;
select * from saleslake_qa.gold_qa.tgtmonthly;
select * from saleslake_prod.gold_prod.tgtmonthly;

-----------------------------------------------------------------------------------


create or replace table salesLake_prod.silver_prod.CleanseMonthlysale
(
    sale_id integer,
    product string,
    category string,
    quantity integer,
    price double,
    sale_date date,
    region string,
    ingest_ts timestamp

);


----------------------------------------------------------


create or replace table salesLake_dev.silver_dev.CleanseMonthlysale
(
    sale_id integer,
    product string,
    category string,
    quantity integer,
    price double,
    sale_date date,
    region string,
    ingest_ts timestamp

);


-----------------------------------------------

create or replace table salesLake_qa.silver_qa.CleanseMonthlysale
(
    sale_id integer,
    product string,
    category string,
    quantity integer,
    price double,
    sale_date date,
    region string,
    ingest_ts timestamp

);

---------------------------------------------------

create or replace table salesLake_dev.gold_dev.tgtmonthly
(
    sale_id integer,
    product string,
    category string,
    quantity integer,
    price double,
    sale_date date,
    region string,
    initial_load_ts timestamp,
    last_updt_ts timestamp

);


----------------------------------------------------------------


create or replace table salesLake_qa.gold_qa.tgtmonthly
(
    sale_id integer,
    product string,
    category string,
    quantity integer,
    price double,
    sale_date date,
    region string,
    initial_load_ts timestamp,
    last_updt_ts timestamp

);
-------------------------------------------


create or replace table saleslake_prod.gold_prod.tgtmonthly
(
    sale_id integer,
    product string,
    category string,
    quantity integer,
    price double,
    sale_date date,
    region string,
    initial_load_ts timestamp,
    last_updt_ts timestamp

);
