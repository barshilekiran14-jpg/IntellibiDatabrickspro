# %%
# %sql
-- truncate table intellibi_catlog.intelischema.rawmonthlysales;
-- truncate table intellibi_catlog.intelischema.CleanseMonthlysale;
-- truncate table intellibi_catlog.intelischema.tgtmonthly;
-- ------------------------------\
select * from intellibi_catlog.intelischema.rawmonthlysales;
-- select * from intellibi_catlog.intelischema.CleanseMonthlysale;
-- select * from intellibi_catlog.intelischema.tgtmonthly;
-- --``

# %%
# %run /Workspace/IntelliBi_Databricks/IntellibiDatabrickspro/bronze/file_to_bronze

# %%
# %run /Workspace/IntelliBi_Databricks/IntellibiDatabrickspro/silver/bronze_to_silver

# %%
# %run /Workspace/IntelliBi_Databricks/IntellibiDatabrickspro/gold/silver_to_gold

# %%
# %run /Workspace/Users/barshilekiran14@gmail.com/silver_to_gold_Scd2
